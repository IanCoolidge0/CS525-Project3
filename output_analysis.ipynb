# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("rewards.txt", "r") as f:
    lines = f.readlines()

# %%
x = np.array(list(map(lambda x: float(x[:-3]), lines[1:])))

# %%
plt.plot(x)

# %%
len(x)
# Out:
# 15970
